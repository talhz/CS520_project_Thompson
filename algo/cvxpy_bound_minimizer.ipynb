# %% [markdown]
# ### Lower Bound
#
# $$minimize \frac{1}{2}\sum_{i!=j}(1+y_{ij})$$

# %%
import cvxpy as cp
import numpy as np

# Define the problem data
n = 10 # number of variables
y = cp.Variable((n,n), symmetric=True) # variable
constraints = [y[i,i] == 1 for i in range(n)] # equality constraints
for i in range(n):
    for j in range(i):
        constraints += [-1 <= y[i,j], y[i,j] <= 1] # inequality constraints
constraints += [y >> 0] # semidefinite constraint
#f = cp.sum(cp.inv_pos(1-y[np.triu_indices(n,1)])) # objective function
f = cp.sum(1+y[np.triu_indices(n,1)]) # objective function

# Define the optimization problem
problem = cp.Problem(cp.Minimize(f), constraints)

# Solve the problem
problem.solve(cp.SCS, verbose=True)
print("Optimal value: ", problem.value)
print("Optimal y: ", y.value)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:31:26 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:31:26 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:31:26 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:31:26 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:31:26 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:31:26 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:31:26 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:31:26 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:31:26 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:31:26 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:31:26 PM: Finished problem compilation (took 5.681e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:31:26 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.66e+00  4.37e-01  1.95e+02 -1.13e+02  1.00e-01  1.26e-03
#     50| 4.75e-12  1.32e-11  2.57e-10 -5.00e+00  1.00e-01  1.75e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.75e-02s = setup: 6.25e-04s + solve: 1.69e-02s
# 	 lin-sys: 1.14e-04s, cones: 1.49e-02s, accel: 1.05e-04s
# ------------------------------------------------------------------
# objective = -5.000000
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:31:26 PM: Problem status: optimal
# (CVXPY) Apr 09 06:31:26 PM: Optimal value: 4.000e+01
# (CVXPY) Apr 09 06:31:26 PM: Compilation took 5.681e-02 seconds
# (CVXPY) Apr 09 06:31:26 PM: Solver (including time spent in interface) took 1.791e-02 seconds
# Optimal value:  40.00000000016815
# Optimal y:  [[ 1.         -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111  1.         -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111  1.         -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111  1.         -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111  1.         -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111  1.
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#    1.         -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111  1.         -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111  1.         -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111  1.        ]]

# %%
print("Optimal value: ", problem.value)
print("Optimal y: ", y.value)
# Out:
# Optimal value:  40.00000000016815
# Optimal y:  [[ 1.         -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111  1.         -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111  1.         -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111  1.         -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111  1.         -0.11111111
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111  1.
#   -0.11111111 -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#    1.         -0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111  1.         -0.11111111 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111  1.         -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111 -0.11111111
#   -0.11111111 -0.11111111 -0.11111111  1.        ]]

# %% [markdown]
# ### Upper Bound
#
# $$minimize (\frac{1}{4}+\frac{1}{4\epsilon})n(n-1)+\frac{1}{2\epsilon}\sum_{i!=j}y_{ij}$$

# %%
import cvxpy as cp
import numpy as np

def upper_bound(eps, n=10):
    y = cp.Variable((n,n), symmetric=True) # variable
    constraints = [y[i,i] == 1 for i in range(n)] # equality constraints
    for i in range(n):
        for j in range(i):
            constraints += [-1 <= y[i,j], y[i,j] <= 1] # inequality constraints
    constraints += [y >> 0] # semidefinite constraint
    #f = cp.sum(cp.inv_pos(1-y[np.triu_indices(n,1)])) # objective function
    f = (1/4+1/(4*eps))*(n*(n-1))+1/(1*eps)*cp.sum(y[np.triu_indices(n,1)]) # objective function

    # Define the optimization problem
    problem = cp.Problem(cp.Minimize(f), constraints)

    # Solve the problem
    problem.solve(cp.SCS, verbose=True)
    # print("Optimal value: ", problem.value)
    # print("Optimal y: ", y.value)
    return problem.value, y.value

# %%
n = 10 # number of variables
eps = 0.1
eps = [i/100 for i in range(100, 0, -1)]
print(eps)
bound_value = []

for e in eps:
    val, _ = upper_bound(e, 10)
    bound_value.append(val)
    print("epsilon: ", e, "Optimal value: ", val)
# Out:
# [1.0, 0.99, 0.98, 0.97, 0.96, 0.95, 0.94, 0.93, 0.92, 0.91, 0.9, 0.89, 0.88, 0.87, 0.86, 0.85, 0.84, 0.83, 0.82, 0.81, 0.8, 0.79, 0.78, 0.77, 0.76, 0.75, 0.74, 0.73, 0.72, 0.71, 0.7, 0.69, 0.68, 0.67, 0.66, 0.65, 0.64, 0.63, 0.62, 0.61, 0.6, 0.59, 0.58, 0.57, 0.56, 0.55, 0.54, 0.53, 0.52, 0.51, 0.5, 0.49, 0.48, 0.47, 0.46, 0.45, 0.44, 0.43, 0.42, 0.41, 0.4, 0.39, 0.38, 0.37, 0.36, 0.35, 0.34, 0.33, 0.32, 0.31, 0.3, 0.29, 0.28, 0.27, 0.26, 0.25, 0.24, 0.23, 0.22, 0.21, 0.2, 0.19, 0.18, 0.17, 0.16, 0.15, 0.14, 0.13, 0.12, 0.11, 0.1, 0.09, 0.08, 0.07, 0.06, 0.05, 0.04, 0.03, 0.02, 0.01]
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:18 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:18 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:18 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:18 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:18 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:18 PM: Finished problem compilation (took 5.804e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.66e+00  4.37e-01  1.95e+02 -1.13e+02  1.00e-01  1.15e-03
#     50| 4.75e-12  1.32e-11  2.57e-10 -5.00e+00  1.00e-01  1.89e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.89e-02s = setup: 4.22e-04s + solve: 1.85e-02s
# 	 lin-sys: 1.24e-04s, cones: 1.65e-02s, accel: 9.53e-05s
# ------------------------------------------------------------------
# objective = -5.000000
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:18 PM: Optimal value: 4.000e+01
# (CVXPY) Apr 09 06:30:18 PM: Compilation took 5.804e-02 seconds
# (CVXPY) Apr 09 06:30:18 PM: Solver (including time spent in interface) took 1.934e-02 seconds
# epsilon:  1.0 Optimal value:  40.00000000016815
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:18 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:18 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:18 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:18 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:18 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:18 PM: Finished problem compilation (took 1.048e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.72e+00  4.40e-01  1.98e+02 -1.15e+02  1.00e-01  1.37e-03
#     50| 9.33e-12  8.37e-12  3.85e-10 -5.05e+00  1.00e-01  1.63e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.63e-02s = setup: 5.07e-04s + solve: 1.58e-02s
# 	 lin-sys: 1.18e-04s, cones: 1.41e-02s, accel: 8.72e-05s
# ------------------------------------------------------------------
# objective = -5.050505
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:18 PM: Optimal value: 4.018e+01
# (CVXPY) Apr 09 06:30:18 PM: Compilation took 1.048e-01 seconds
# (CVXPY) Apr 09 06:30:18 PM: Solver (including time spent in interface) took 1.685e-02 seconds
# epsilon:  0.99 Optimal value:  40.17676767710104
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:18 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:18 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:18 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:18 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:18 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:18 PM: Finished problem compilation (took 5.427e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.78e+00  4.43e-01  2.03e+02 -1.17e+02  1.00e-01  1.71e-03
#     50| 1.00e-11  4.23e-12  3.84e-10 -5.10e+00  1.00e-01  1.71e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.71e-02s = setup: 7.10e-04s + solve: 1.64e-02s
# 	 lin-sys: 1.13e-04s, cones: 1.45e-02s, accel: 9.32e-05s
# ------------------------------------------------------------------
# objective = -5.102041
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:18 PM: Optimal value: 4.036e+01
# (CVXPY) Apr 09 06:30:18 PM: Compilation took 5.427e-02 seconds
# (CVXPY) Apr 09 06:30:18 PM: Solver (including time spent in interface) took 1.763e-02 seconds
# epsilon:  0.98 Optimal value:  40.35714285750526
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:18 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:18 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:18 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:18 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:18 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:18 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:18 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 5.368e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.84e+00  4.46e-01  2.07e+02 -1.20e+02  1.00e-01  1.55e-03
#     50| 8.20e-12  1.37e-12  3.01e-10 -5.15e+00  1.00e-01  1.53e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.53e-02s = setup: 7.02e-04s + solve: 1.46e-02s
# 	 lin-sys: 1.09e-04s, cones: 1.28e-02s, accel: 8.70e-05s
# ------------------------------------------------------------------
# objective = -5.154639
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.054e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 5.368e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 1.585e-02 seconds
# epsilon:  0.97 Optimal value:  40.54123711370059
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 5.659e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.91e+00  4.50e-01  2.11e+02 -1.22e+02  1.00e-01  1.51e-03
#     25| 1.07e-06  1.17e-06  2.41e-05 -5.21e+00  1.00e-01  9.60e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 9.60e-03s = setup: 8.81e-04s + solve: 8.72e-03s
# 	 lin-sys: 6.43e-05s, cones: 7.72e-03s, accel: 2.70e-05s
# ------------------------------------------------------------------
# objective = -5.208357
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.073e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 5.659e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 1.012e-02 seconds
# epsilon:  0.96 Optimal value:  40.729131436772605
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 5.733e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.97e+00  4.53e-01  2.16e+02 -1.25e+02  1.00e-01  1.54e-03
#     25| 6.61e-07  4.27e-07  1.11e-06 -5.26e+00  1.00e-01  1.10e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.10e-02s = setup: 8.71e-04s + solve: 1.01e-02s
# 	 lin-sys: 5.87e-05s, cones: 8.83e-03s, accel: 2.44e-05s
# ------------------------------------------------------------------
# objective = -5.263164
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.092e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 5.733e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 1.144e-02 seconds
# epsilon:  0.95 Optimal value:  40.92104585109325
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 8.798e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.04e+00  4.56e-01  2.20e+02 -1.28e+02  1.00e-01  1.83e-03
#     25| 7.13e-07  4.54e-07  4.10e-06 -5.32e+00  1.00e-01  1.28e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.28e-02s = setup: 7.60e-04s + solve: 1.21e-02s
# 	 lin-sys: 6.73e-05s, cones: 1.07e-02s, accel: 3.39e-05s
# ------------------------------------------------------------------
# objective = -5.319151
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.112e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 8.798e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 1.331e-02 seconds
# epsilon:  0.94 Optimal value:  41.11701734122213
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 5.436e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.11e+00  4.60e-01  2.25e+02 -1.30e+02  1.00e-01  1.64e-03
#     25| 7.67e-07  1.22e-06  2.40e-05 -5.38e+00  1.00e-01  8.89e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 8.89e-03s = setup: 6.27e-04s + solve: 8.26e-03s
# 	 lin-sys: 7.83e-05s, cones: 7.18e-03s, accel: 2.43e-05s
# ------------------------------------------------------------------
# objective = -5.376351
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.132e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 5.436e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 9.376e-03 seconds
# epsilon:  0.93 Optimal value:  41.31718503682907
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 8.627e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.17e+00  4.63e-01  2.30e+02 -1.33e+02  1.00e-01  1.45e-03
#     25| 1.31e-06  1.81e-06  5.82e-05 -5.43e+00  1.00e-01  8.32e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 8.33e-03s = setup: 7.22e-04s + solve: 7.60e-03s
# 	 lin-sys: 7.40e-05s, cones: 6.54e-03s, accel: 2.40e-05s
# ------------------------------------------------------------------
# objective = -5.434804
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.152e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 8.627e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 8.739e-03 seconds
# epsilon:  0.92 Optimal value:  41.52168870968918
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 5.609e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.25e+00  4.67e-01  2.35e+02 -1.36e+02  1.00e-01  1.44e-03
#     50| 5.17e-12  2.95e-12  2.17e-10 -5.49e+00  1.00e-01  1.94e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.94e-02s = setup: 7.21e-04s + solve: 1.86e-02s
# 	 lin-sys: 1.42e-04s, cones: 1.65e-02s, accel: 1.09e-04s
# ------------------------------------------------------------------
# objective = -5.494505
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.173e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 5.609e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 1.992e-02 seconds
# epsilon:  0.91 Optimal value:  41.73076923096962
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 5.599e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.32e+00  4.71e-01  2.40e+02 -1.39e+02  1.00e-01  1.53e-03
#     50| 7.80e-12  1.85e-12  3.12e-10 -5.56e+00  1.00e-01  4.61e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.61e-02s = setup: 5.74e-04s + solve: 4.55e-02s
# 	 lin-sys: 1.33e-04s, cones: 4.35e-02s, accel: 9.45e-05s
# ------------------------------------------------------------------
# objective = -5.555556
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.194e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 5.599e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 4.662e-02 seconds
# epsilon:  0.9 Optimal value:  41.94444444475044
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 5.661e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.39e+00  4.75e-01  2.46e+02 -1.42e+02  1.00e-01  3.27e-03
#     50| 9.56e-12  9.00e-13  3.70e-10 -5.62e+00  1.00e-01  2.35e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 2.35e-02s = setup: 3.06e-04s + solve: 2.32e-02s
# 	 lin-sys: 1.20e-04s, cones: 2.14e-02s, accel: 9.90e-05s
# ------------------------------------------------------------------
# objective = -5.617978
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:19 PM: Optimal value: 4.216e+01
# (CVXPY) Apr 09 06:30:19 PM: Compilation took 5.661e-02 seconds
# (CVXPY) Apr 09 06:30:19 PM: Solver (including time spent in interface) took 2.411e-02 seconds
# epsilon:  0.89 Optimal value:  42.16292134869405
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:19 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:19 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:19 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:19 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:19 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:19 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:19 PM: Finished problem compilation (took 5.541e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:19 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.47e+00  4.79e-01  2.52e+02 -1.45e+02  1.00e-01  1.81e-03
#     50| 9.82e-12  2.51e-12  3.68e-10 -5.68e+00  1.00e-01  1.79e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.79e-02s = setup: 8.63e-04s + solve: 1.70e-02s
# 	 lin-sys: 1.15e-04s, cones: 1.52e-02s, accel: 1.01e-04s
# ...
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.19e+02  6.25e+00  8.34e+04 -4.23e+04  1.00e-01  1.55e-03
#    150| 2.65e-07  5.19e-07  1.81e-04 -1.00e+02  5.54e+00  4.34e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.35e-02s = setup: 6.42e-04s + solve: 4.28e-02s
# 	 lin-sys: 3.24e-04s, cones: 3.83e-02s, accel: 3.10e-04s
# ------------------------------------------------------------------
# objective = -100.000097
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:29 PM: Optimal value: 3.725e+02
# (CVXPY) Apr 09 06:30:29 PM: Compilation took 9.709e-02 seconds
# (CVXPY) Apr 09 06:30:29 PM: Solver (including time spent in interface) took 4.402e-02 seconds
# epsilon:  0.05 Optimal value:  372.4998128372503
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:29 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:29 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:29 PM: Finished problem compilation (took 5.876e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.48e+02  7.78e+00  1.31e+05 -6.60e+04  1.00e-01  3.32e-03
#    175| 1.18e-06  2.51e-05  8.47e-04 -1.25e+02  1.18e+01  1.02e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.02e-01s = setup: 7.29e-04s + solve: 1.01e-01s
# 	 lin-sys: 4.04e-04s, cones: 9.46e-02s, accel: 3.88e-04s
# ------------------------------------------------------------------
# objective = -124.999380
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:29 PM: Optimal value: 4.600e+02
# (CVXPY) Apr 09 06:30:29 PM: Compilation took 5.876e-02 seconds
# (CVXPY) Apr 09 06:30:29 PM: Solver (including time spent in interface) took 1.039e-01 seconds
# epsilon:  0.04 Optimal value:  460.00104309145996
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:29 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:29 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:29 PM: Finished problem compilation (took 6.319e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.98e+02  1.03e+01  2.32e+05 -1.17e+05  1.00e-01  1.33e-03
#    175| 1.19e-07  2.53e-06  1.21e-04 -1.67e+02  8.20e+00  8.53e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 8.53e-02s = setup: 5.42e-04s + solve: 8.48e-02s
# 	 lin-sys: 4.09e-04s, cones: 7.94e-02s, accel: 3.62e-04s
# ------------------------------------------------------------------
# objective = -166.666587
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:29 PM: Optimal value: 6.058e+02
# (CVXPY) Apr 09 06:30:29 PM: Compilation took 6.319e-02 seconds
# (CVXPY) Apr 09 06:30:29 PM: Solver (including time spent in interface) took 8.579e-02 seconds
# epsilon:  0.03 Optimal value:  605.8334739353866
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:29 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:29 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:29 PM: Finished problem compilation (took 9.497e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.97e+02  1.54e+01  5.24e+05 -2.63e+05  1.00e-01  1.14e-03
#    200| 1.14e-08  2.56e-05  1.61e-04 -2.50e+02  4.00e+01  5.47e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.47e-02s = setup: 5.53e-04s + solve: 5.41e-02s
# 	 lin-sys: 4.30e-04s, cones: 4.83e-02s, accel: 4.12e-04s
# ------------------------------------------------------------------
# objective = -250.000101
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:29 PM: Optimal value: 8.975e+02
# (CVXPY) Apr 09 06:30:29 PM: Compilation took 9.497e-02 seconds
# (CVXPY) Apr 09 06:30:29 PM: Solver (including time spent in interface) took 5.530e-02 seconds
# epsilon:  0.02 Optimal value:  897.4999798291151
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 06:30:29 PM: Your problem has 100 variables, 101 constraints, and 0 parameters.
# (CVXPY) Apr 09 06:30:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 06:30:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 06:30:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 06:30:29 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 06:30:29 PM: Applying reduction SCS
# (CVXPY) Apr 09 06:30:29 PM: Finished problem compilation (took 8.049e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 155
# cones: 	  z: primal zero / dual free vars: 10
# 	  l: linear vars: 90
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 155, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.94e+02  3.07e+01  2.10e+06 -1.05e+06  1.00e-01  1.42e-03
#    200| 1.43e-08  2.91e-04  1.98e-03 -5.00e+02  7.81e+02  8.05e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 8.05e-02s = setup: 4.20e-04s + solve: 8.01e-02s
# 	 lin-sys: 4.37e-04s, cones: 7.40e-02s, accel: 4.13e-04s
# ------------------------------------------------------------------
# objective = -499.998961
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 06:30:29 PM: Problem status: optimal
# (CVXPY) Apr 09 06:30:29 PM: Optimal value: 1.773e+03
# (CVXPY) Apr 09 06:30:29 PM: Compilation took 8.049e-02 seconds
# (CVXPY) Apr 09 06:30:29 PM: Solver (including time spent in interface) took 8.081e-02 seconds
# epsilon:  0.01 Optimal value:  1772.5000504091597

# %%
import matplotlib.pyplot as plt

plt.plot(eps, bound_value)
plt.title(f'Upper Bound w.r.t. epsilon')
plt.xlabel('epsilon')
plt.ylabel('bounded value')
plt.legend()
plt.savefig("upper_bound.png")
print(bound_value)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [40.00000000016815, 40.17676767710104, 40.35714285750526, 40.54123711370059, 40.729131436772605, 40.92104585109325, 41.11701734122213, 41.31718503682907, 41.52168870968918, 41.73076923096962, 41.94444444475044, 42.16292134869405, 42.386363636757935, 42.61494252907631, 42.84883720952428, 43.08823529417485, 43.33333333325706, 43.5843373492651, 43.841463414486526, 44.10493827145782, 44.37499999985168, 44.651898734018104, 44.935897435714104, 45.227272727064886, 45.5263157892489, 45.83333333311303, 46.148648648465006, 46.47260273960962, 46.80555555552456, 47.147887323956915, 47.500000000021515, 47.86231884059235, 48.23529411765785, 48.61940298510218, 49.0151515152206, 49.423076923197506, 49.84375000017331, 50.27777777798673, 50.72580645175212, 51.18852459024903, 51.666666666731345, 52.16101694923266, 52.67241379321821, 53.201754386115255, 53.75000000015945, 54.3181818182934, 54.907407407468995, 55.51886792461105, 56.15384615397561, 56.813725490386105, 57.50000000026633, 58.214285714460914, 58.95833333338938, 59.734042553169175, 60.543478260818425, 61.38888888885702, 62.272727272605714, 63.19767441827462, 64.16666666603679, 65.18292682851943, 66.24999999999106, 67.3717948725165, 68.55263158035953, 69.79729729786642, 71.11111111117978, 72.4999999998138, 73.97058823380917, 75.53030302671193, 77.18750000069427, 78.95161291004086, 80.8333333354046, 82.8448275804945, 84.99999999097221, 87.31481481233243, 89.80769237158769, 92.49999992061373, 95.41666668604586, 98.58695664330155, 102.04545428444143, 105.8333336405715, 109.99999926509437, 114.60526625349682, 119.72221657793942, 125.44120790739143, 131.87509497744009, 139.16691111756245, 147.50000000007978, 157.1153846151954, 168.33333332720542, 181.5909091627961, 197.50000126150576, 216.94454464171085, 241.24999999936003, 272.5000000020873, 314.16666669198815, 372.4998128372503, 460.00104309145996, 605.8334739353866, 897.4999798291151, 1772.5000504091597]

# %% [markdown]
# ### Equivalent Eigenvalue Bound Problem

# %%
import cvxpy as cp
import numpy as np

# Define the problem data
n = 10 # number of variables
y = cp.Variable((n,n), symmetric=True) # variable
W = (np.ones((n,n))-np.diag(np.ones(n)))
#W = (np.ones((n,n)))
#print(cp.diag(W*y))
constraints = [(W + cp.diag(cp.diag(W*y))) >> 0]
# print(W)
constraints += [y[i,i] == 1 for i in range(n)] # equality constraints
# for i in range(n):
#     # for j in range(i):
#     #     constraints += [-1 <= y[i,j], y[i,j] <= 1] # inequality constraints
# #constraints += [y >> 0] # semidefinite constraint
# constraints = W + 
# #f = cp.sum(cp.inv_pos(1-y[np.triu_indices(n,1)])) # objective function
f = 1/2*(n*(n-1)) - 1/2 * cp.sum(cp.diag(W*y)) # objective function

# # Define the optimization problem
problem = cp.Problem(cp.Maximize(f), constraints)
#problem = cp.Problem(cp.Minimize(f), constraints)

# # Solve the problem
problem.solve(cp.SCS, verbose=True)
print("Optimal value: ", problem.value)
print("Optimal y: ", y.value)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 09 09:51:35 PM: Your problem has 100 variables, 11 constraints, and 0 parameters.
# (CVXPY) Apr 09 09:51:35 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 09 09:51:35 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 09 09:51:35 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 09:51:35 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 09 09:51:35 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 09 09:51:35 PM: Applying reduction FlipObjective
# (CVXPY) Apr 09 09:51:35 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 09 09:51:35 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 09 09:51:35 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 09 09:51:35 PM: Applying reduction SCS
# (CVXPY) Apr 09 09:51:35 PM: Finished problem compilation (took 1.641e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 09:51:35 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 55, constraints m: 65
# cones: 	  z: primal zero / dual free vars: 10
# 	  s: psd vars: 55, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 100, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.71e+00  1.46e+00  3.96e+01 -7.49e+00  1.00e-01  1.79e-03
#     25| 2.12e-06  1.03e-08  1.19e-05  5.00e+00  1.00e-01  1.23e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.23e-02s = setup: 7.61e-04s + solve: 1.15e-02s
# 	 lin-sys: 4.00e-05s, cones: 1.07e-02s, accel: 1.46e-05s
# ------------------------------------------------------------------
# objective = 4.999994
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 09 09:51:35 PM: Problem status: optimal
# (CVXPY) Apr 09 09:51:35 PM: Optimal value: 4.000e+01
# (CVXPY) Apr 09 09:51:35 PM: Compilation took 1.641e-02 seconds
# (CVXPY) Apr 09 09:51:35 PM: Solver (including time spent in interface) took 1.268e-02 seconds
# Optimal value:  40.000011912739
# Optimal y:  [[0.99999997 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.99999997 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.99999997 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.99999997 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.99999997 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.99999997
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.99999997 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.99999997 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.99999997 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.99999997]]
# /Users/zhaorunchen/opt/anaconda3/lib/python3.9/site-packages/cvxpy/expressions/expression.py:612: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 53 times so far.
#
#   warnings.warn(msg, UserWarning)
# /Users/zhaorunchen/opt/anaconda3/lib/python3.9/site-packages/cvxpy/expressions/expression.py:612: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 54 times so far.
#
#   warnings.warn(msg, UserWarning)

# %%
print("Optimal value: ", problem.value)
print("Optimal y: ", y.value)
# Out:
# Optimal value:  40.000011912739
# Optimal y:  [[0.99999997 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.99999997 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.99999997 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.99999997 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.99999997 0.11111085
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.99999997
#   0.11111085 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.99999997 0.11111085 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.99999997 0.11111085 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.99999997 0.11111085]
#  [0.11111085 0.11111085 0.11111085 0.11111085 0.11111085 0.11111085
#   0.11111085 0.11111085 0.11111085 0.99999997]]
